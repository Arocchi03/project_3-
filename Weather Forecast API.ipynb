# %%
import matplotlib.pyplot as plt
import requests
from scipy import stats
import pandas as pd

# %%
# Save config information
url = "https://weather.visualcrossing.com/VisualCrossingWebServices/rest/services/weatherdata/forecast?aggregateHours=24&combinationMethod=aggregate&contentType=csv&unitGroup=us&locationMode=single&key=N3SXXVZ89UWW9YLFTJGZJJANB&dataElements=default&locations=Chicago"

# %%
forecast_data = pd.read_csv(url)

# %%
forecast_data.head()
# Out:
#       Name   Date time  Maximum Temperature  Minimum Temperature  Temperature  \
# 0  Chicago  05/24/2021                 83.0                 83.0         83.0
# 1  Chicago  05/25/2021                 81.9                 67.9         76.0
# 2  Chicago  05/26/2021                 70.1                 59.6         66.5
# 3  Chicago  05/27/2021                 58.4                 54.1         56.0
# 4  Chicago  05/28/2021                 55.1                 49.9         52.0
#
#    Wind Chill  Heat Index  Chance Precipitation (%)  Precipitation  Snow  \
# 0         NaN        82.8                       1.0           0.00   0.0
# 1         NaN        82.2                      35.0           0.04   0.0
# 2         NaN         NaN                      62.0           0.20   0.0
# 3         NaN         NaN                      75.0           0.14   0.0
# 4        44.3         NaN                      75.0           0.06   0.0
#
# ...

# %%
forecast_updated = forecast_data.drop(["Name", "Wind Chill", "Heat Index","Wind Gust"], axis=1)
forecast_updated.head()
# Out:
#     Date time  Maximum Temperature  Minimum Temperature  Temperature  \
# 0  05/24/2021                 83.0                 83.0         83.0
# 1  05/25/2021                 81.9                 67.9         76.0
# 2  05/26/2021                 70.1                 59.6         66.5
# 3  05/27/2021                 58.4                 54.1         56.0
# 4  05/28/2021                 55.1                 49.9         52.0
#
#    Chance Precipitation (%)  Precipitation  Snow  Snow Depth  Wind Speed  \
# 0                       1.0           0.00   0.0         0.0         8.6
# 1                      35.0           0.04   0.0         0.0        14.7
# 2                      62.0           0.20   0.0         0.0        11.0
# 3                      75.0           0.14   0.0         0.0        13.0
# 4                      75.0           0.06   0.0         0.0        15.7
#
#    Visibility  Cloud Cover  Relative Humidity              Conditions
# ...

# %%
forecast
